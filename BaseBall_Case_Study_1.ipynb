# %% [markdown]
# # BaseBall Case Study

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.rename(columns = {'2B': 'Double', '3B': 'Triple'}, inplace = True)

# %%
df
# Out:
#       W    R    AB     H  Double  Triple   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95  724  5575  1497     300      42  139  383   973  104  641  601  3.73
# 1    83  696  5467  1349     277      44  156  439  1264   70  700  653  4.07
# 2    81  669  5439  1395     303      29  141  533  1157   86  640  584  3.67
# 3    76  622  5533  1381     260      27  136  404  1231   68  701  643  3.98
# 4    74  689  5605  1515     289      49  151  455  1259   83  803  746  4.64
# 5    93  891  5509  1480     308      17  232  570  1151   88  670  609  3.80
# 6    87  764  5567  1397     272      19  212  554  1227   63  698  652  4.03
# 7    81  713  5485  1370     246      20  217  418  1331   44  693  646  4.05
# 8    80  644  5485  1383     278      32  167  436  1310   87  642  604  3.74
# 9    78  748  5640  1495     294      33  161  478  1148   71  753  694  4.31
# 10   88  751  5511  1419     279      32  172  503  1233  101  733  680  4.24
# 11   86  729  5459  1363     278      26  230  486  1392  121  618  572  3.57
# 12   85  661  5417  1331     243      21  176  435  1150   52  675  630  3.94
# 13   76  656  5544  1379     262      22  198  478  1336   69  726  677  4.16
# 14   68  694  5600  1405     277      46  146  475  1119   78  729  664  4.14
# 15  100  647  5484  1386     288      39  137  506  1267   69  525  478  2.94
# 16   98  697  5631  1462     292      27  140  461  1322   98  596  532  3.21
# 17   97  689  5491  1341     272      30  171  567  1518   95  608  546  3.36
# 18   68  655  5480  1378     274      34  145  412  1299   84  737  682  4.28
# 19   64  640  5571  1382     257      27  167  496  1255  134  754  700  4.33
# 20   90  683  5527  1351     295      17  177  488  1290   51  613  557  3.43
# 21   83  703  5428  1363     265      13  177  539  1344   57  635  577  3.62
# 22   71  613  5463  1420     236      40  120  375  1150  112  678  638  4.02
# 23   67  573  5420  1361     251      18  100  471  1107   69  760  698  4.41
# 24   63  626  5529  1374     272      37  130  387  1274   88  809  749  4.69
# 25   92  667  5385  1346     263      26  187  563  1258   59  595  553  3.44
# 26   84  696  5565  1486     288      39  136  457  1159   93  627  597  3.72
# 27   79  720  5649  1494     289      48  154  490  1312  132  713  659  4.04
# 28   74  650  5457  1324     260      36  148  426  1327   82  731  655  4.09
# 29   68  737  5572  1479     274      49  186  388  1283   97  844  799  5.04
#
#     CG  SHO  SV    E
# 0    2    8  56   88
# 1    2   12  45   86
# 2   11   10  38   79
# 3    7    9  37  101
# 4    7   12  35   86
# 5    7   10  34   88
# 6    3    4  48   93
# 7    0   10  43   77
# 8    1   12  60   95
# 9    3   10  40   97
# 10   5    9  45  119
# 11   5   13  39   85
# 12   2   12  46   93
# 13   6   12  45   94
# 14   5   15  28  126
# 15   1   15  62   96
# 16   0   13  54  122
# 17   6   21  48  111
# 18   1    7  40  116
# 19   2    8  35   90
# 20   1   14  50   88
# 21   4   13  41   90
# 22   0   12  35   77
# 23   3   10  44   90
# 24   1    7  35  117
# 25   6   21  47   75
# 26   7   18  41   78
# 27   1   12  44   86
# 28   1    6  41   92
# 29   4    4  36   95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   Double  30 non-null     int64
#  5   Triple  30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# There is no null values in the dataset and all are integer values only ERA has float value.

# %%
df.isnull().sum()
# Out:
# W         0
# R         0
# AB        0
# H         0
# Double    0
# Triple    0
# HR        0
# BB        0
# SO        0
# SB        0
# RA        0
# ER        0
# ERA       0
# CG        0
# SHO       0
# SV        0
# E         0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#         count         mean         std      min        25%       50%      75%  \
# W        30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R        30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB       30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H        30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# Double   30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# Triple   30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR       30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB       30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO       30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB       30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA       30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ER       30.0   635.833333   70.140786   478.00   587.2500   644.500   679.25
# ERA      30.0     3.956333    0.454089     2.94     3.6825     4.025     4.22
# CG       30.0     3.466667    2.763473     0.00     1.0000     3.000     5.75
# SHO      30.0    11.300000    4.120177     4.00     9.0000    12.000    13.00
# SV       30.0    43.066667    7.869335    28.00    37.2500    42.000    46.75
# E        30.0    94.333333   13.958889    75.00    86.0000    91.000    96.75
#
#             max
# W        100.00
# R        891.00
# AB      5649.00
# H       1515.00
# Double   308.00
# Triple    49.00
# HR       232.00
# BB       570.00
# SO      1518.00
# SB       134.00
# RA       844.00
# ER       799.00
# ERA        5.04
# CG        11.00
# SHO       21.00
# SV        62.00
# E        126.00

# %% [markdown]
# As we see that in the count column all values are same so the dataset looks perfect.
# In the mean and median percentile, some values of median is greater and in some columns mean is greater so we can not understand thaat the skewness in which direction.
# There is difference between std deviation and 75% percentile.

# %%
dfcor = df.corr().abs()
dfcor
# Out:
#                W         R        AB         H    Double    Triple        HR  \
# W       1.000000  0.430751  0.087947  0.037612  0.427797  0.251118  0.307407
# R       0.430751  1.000000  0.319464  0.482856  0.560084  0.070072  0.671283
# AB      0.087947  0.319464  1.000000  0.739122  0.453370  0.435422  0.066983
# H       0.037612  0.482856  0.739122  1.000000  0.566847  0.478694  0.090855
# Double  0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# Triple  0.251118  0.070072  0.435422  0.478694  0.220490  1.000000  0.430915
# HR      0.307407  0.671283  0.066983  0.090855  0.056292  0.430915  1.000000
# BB      0.484342  0.402452  0.136414  0.118281  0.302700  0.454949  0.425691
# SO      0.111850  0.054726  0.106022  0.398830  0.150752  0.141196  0.359923
# SB      0.157234  0.081367  0.372618  0.413444  0.195027  0.457437  0.136567
# RA      0.812952  0.041623  0.316010  0.224324  0.218160  0.314125  0.103903
# ER      0.809435  0.041245  0.309686  0.252489  0.235531  0.340225  0.085922
# ERA     0.819600  0.049281  0.255551  0.231172  0.254854  0.330951  0.090917
# CG      0.080533  0.232042  0.080876  0.147955  0.306675  0.065898  0.156502
# SHO     0.471805  0.103274  0.197321  0.145559  0.057998  0.041396  0.019119
# SV      0.666530  0.096380  0.106367  0.130371  0.171576  0.142370  0.028540
# E       0.089485  0.023262  0.316743  0.033173  0.105754  0.126678  0.207597
#
#               BB        SO        SB        RA        ER       ERA        CG  \
# W       0.484342  0.111850  0.157234  0.812952  0.809435  0.819600  0.080533
# R       0.402452  0.054726  0.081367  0.041623  0.041245  0.049281  0.232042
# AB      0.136414  0.106022  0.372618  0.316010  0.309686  0.255551  0.080876
# H       0.118281  0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# Double  0.302700  0.150752  0.195027  0.218160  0.235531  0.254854  0.306675
# Triple  0.454949  0.141196  0.457437  0.314125  0.340225  0.330951  0.065898
# HR      0.425691  0.359923  0.136567  0.103903  0.085922  0.090917  0.156502
# BB      1.000000  0.233652  0.098347  0.416445  0.452663  0.459832  0.462478
# SO      0.233652  1.000000  0.030968  0.129745  0.161612  0.180368  0.093418
# SB      0.098347  0.030968  1.000000  0.132290  0.143068  0.126063  0.020783
# RA      0.416445  0.129745  0.132290  1.000000  0.991018  0.986674  0.016659
# ER      0.452663  0.161612  0.143068  0.991018  1.000000  0.997248  0.020221
# ERA     0.459832  0.180368  0.126063  0.986674  0.997248  1.000000  0.009856
# CG      0.462478  0.093418  0.020783  0.016659  0.020221  0.009856  1.000000
# SHO     0.426004  0.237721  0.106563  0.636862  0.630192  0.630833  0.241676
# SV      0.099445  0.126297  0.183418  0.616224  0.589663  0.607005  0.367766
# E       0.075685  0.155133  0.079149  0.198996  0.136921  0.113137  0.140047
#
#              SHO        SV         E
# W       0.471805  0.666530  0.089485
# R       0.103274  0.096380  0.023262
# AB      0.197321  0.106367  0.316743
# H       0.145559  0.130371  0.033173
# Double  0.057998  0.171576  0.105754
# Triple  0.041396  0.142370  0.126678
# HR      0.019119  0.028540  0.207597
# BB      0.426004  0.099445  0.075685
# SO      0.237721  0.126297  0.155133
# SB      0.106563  0.183418  0.079149
# RA      0.636862  0.616224  0.198996
# ER      0.630192  0.589663  0.136921
# ERA     0.630833  0.607005  0.113137
# CG      0.241676  0.367766  0.140047
# SHO     1.000000  0.221639  0.115716
# SV      0.221639  1.000000  0.025636
# E       0.115716  0.025636  1.000000

# %%
plt.figure(figsize=(22,16))
sns.heatmap(dfcor, annot= True)
plt.show()

# %% [markdown]
# There seems to be strong correlation between RA, ER and ERA variables. We will check the same using VIF.
# R, ER and ERA having strong relation with Target variable W, we will check the same using Hypothesis Testing and Intercept.
# AB and H, are having correlation values as 0.74, all other variables are having very less correlation values.

# %% [markdown]
# # Univariant Analysis:

# %%
sns.displot(df.R)

# %%
sns.displot(df.H)

# %%
sns.displot(df.AB)

# %%
sns.displot(df.Double)

# %%
sns.displot(df.Triple)

# %%
sns.displot(df.SO)

# %%
sns.displot(df.HR)

# %%
sns.displot(df.RA)

# %% [markdown]
# # Bivariate Analysis

# %%
sns.regplot(x='R', y='W', data = df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.regplot(x='ER', y='W', data = df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.regplot(x='ERA',y = 'W', data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %% [markdown]
# Both ER and ERA variables are negativly related with the Target variable W, whereas R(Run) is having positive linear relation with Target Variable W.

# %%
sns.regplot(x ='R', y='ER',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='ER'>

# %%
sns.regplot(x='R', y= 'ERA', data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='ERA'>

# %%
sns.regplot(x='ER', y='ERA', data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='ERA'>

# %% [markdown]
# It can be clearly seen that R is very weakly realted with ER and ERA, but ER and ERA has a very strongly relation amongst them.

# %%
sns.regplot(x='H', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.regplot(x='AB', y='W', data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %% [markdown]
# H and AB, both are very weakly related with Win, whereas they are strongly related with each other.

# %% [markdown]
# # Checking Skewness :

# %%
x = df.drop(columns='W')
y = df['W']

# %%
x.skew().sort_values(ascending= True)
# Out:
# Double   -0.230650
# SO       -0.156065
# RA        0.045734
# ERA       0.053331
# ER        0.058710
# Triple    0.129502
# BB        0.158498
# AB        0.183437
# SB        0.479893
# HR        0.516441
# SHO       0.565790
# SV        0.657524
# H         0.670254
# CG        0.736845
# E         0.890132
# R         1.200786
# dtype: float64

# %% [markdown]
# There seems to be skewness present in the data, ranging from -0.23 to +1.20.

# %%
plt.figure(figsize = (20,20))
plotnumber = 1

for column in x:
    if plotnumber <= 16:
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(x[column])
        plt.xlabel(column, fontsize = 20)
    plotnumber +=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,20))
fignumber = 1

for columns in x:
    if fignumber<= 16 :
        ax = plt.subplot(4,4,fignumber)
        sns.regplot(x[column], y)
        
    fignumber +=1
    
plt.show()

# %% [markdown]
# The R(number of runs), HR (home runs), 2B(doubles), SV(Saves), SHO(Shutouts), and BB(Walks) are highly positively linearly correlated.
#
# SB(Stolen Bases), RA(Runs Allowed), ER(Earned Runs), ERA(Earned Runs Average) are highly negative linearly correlated.
#
# The remaining features have less to no linear correlation with no of Wins.

# %% [markdown]
# # Checking Outliers:

# %%
df.plot(kind='box', subplots = True, layout =(8,8), figsize=(8,20))
# Out:
# W           AxesSubplot(0.125,0.798085;0.0824468x0.0819149)
# R         AxesSubplot(0.223936,0.798085;0.0824468x0.0819...
# AB        AxesSubplot(0.322872,0.798085;0.0824468x0.0819...
# H         AxesSubplot(0.421809,0.798085;0.0824468x0.0819...
# Double    AxesSubplot(0.520745,0.798085;0.0824468x0.0819...
# Triple    AxesSubplot(0.619681,0.798085;0.0824468x0.0819...
# HR        AxesSubplot(0.718617,0.798085;0.0824468x0.0819...
# BB        AxesSubplot(0.817553,0.798085;0.0824468x0.0819...
# SO          AxesSubplot(0.125,0.699787;0.0824468x0.0819149)
# SB        AxesSubplot(0.223936,0.699787;0.0824468x0.0819...
# RA        AxesSubplot(0.322872,0.699787;0.0824468x0.0819...
# ER        AxesSubplot(0.421809,0.699787;0.0824468x0.0819...
# ERA       AxesSubplot(0.520745,0.699787;0.0824468x0.0819...
# CG        AxesSubplot(0.619681,0.699787;0.0824468x0.0819...
# SHO       AxesSubplot(0.718617,0.699787;0.0824468x0.0819...
# SV        AxesSubplot(0.817553,0.699787;0.0824468x0.0819...
# E           AxesSubplot(0.125,0.601489;0.0824468x0.0819149)
# dtype: object

# %% [markdown]
# There is no outliers are present in the dataset.

# %% [markdown]
# lets check using z_score

# %%
from scipy.stats import zscore
z = np.abs(zscore(x)).all()
z
# Out:
# R         True
# AB        True
# H         True
# Double    True
# Triple    True
# HR        True
# BB        True
# SO        True
# SB        True
# RA        True
# ER        True
# ERA       True
# CG        True
# SHO       True
# SV        True
# E         True
# dtype: bool

# %% [markdown]
# There is no outliers are present in the dataset.

# %% [markdown]
# # Checking Multicolinearity using VIF :

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(x_scaled,i) for i in range (x_scaled.shape[1])]
vif['features'] = x.columns

# %%
vif
# Out:
#             vif features
# 0     11.522370        R
# 1     13.311532       AB
# 2     10.070668        H
# 3      4.019297   Double
# 4      3.294146   Triple
# 5     10.079902       HR
# 6      3.806098       BB
# 7      2.652401       SO
# 8      2.102684       SB
# 9    191.839155       RA
# 10  1680.387145       ER
# 11  1222.722240      ERA
# 12     3.059904       CG
# 13     3.654331      SHO
# 14     5.798850       SV
# 15     2.186219        E

# %% [markdown]
# AS the value of VIF is very high that means, There is a strong correlation between features. Therefore removing the feature with heighest VIF values and then will see the variation in VIF.

# %%
x_new = x.drop(columns = ['ER'], axis = 1)
x_new.head()
# Out:
#      R    AB     H  Double  Triple   HR   BB    SO   SB   RA   ERA  CG  SHO  \
# 0  724  5575  1497     300      42  139  383   973  104  641  3.73   2    8
# 1  696  5467  1349     277      44  156  439  1264   70  700  4.07   2   12
# 2  669  5439  1395     303      29  141  533  1157   86  640  3.67  11   10
# 3  622  5533  1381     260      27  136  404  1231   68  701  3.98   7    9
# 4  689  5605  1515     289      49  151  455  1259   83  803  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x_new)

# %%
vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]

vif['features'] = x_new.columns

# %%
vif
# Out:
#            vif features
# 0    11.158733        R
# 1     5.863764       AB
# 2     9.628749        H
# 3     3.786446   Double
# 4     3.293109   Triple
# 5     9.057309       HR
# 6     3.791451       BB
# 7     2.607389       SO
# 8     1.849280       SB
# 9   122.133235       RA
# 10  119.328698      ERA
# 11    2.741188       CG
# 12    3.410561      SHO
# 13    3.203815       SV
# 14    2.107345        E

# %%
x_new = x.drop(columns = 'ERA', axis = 1)
x_new.head()
# Out:
#      R    AB     H  Double  Triple   HR   BB    SO   SB   RA   ER  CG  SHO  \
# 0  724  5575  1497     300      42  139  383   973  104  641  601   2    8
# 1  696  5467  1349     277      44  156  439  1264   70  700  653   2   12
# 2  669  5439  1395     303      29  141  533  1157   86  640  584  11   10
# 3  622  5533  1381     260      27  136  404  1231   68  701  643   7    9
# 4  689  5605  1515     289      49  151  455  1259   83  803  746   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_new)

# %%
vif  = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['features'] = x_new.columns
vif
# Out:
#            vif features
# 0    11.375311        R
# 1     4.464580       AB
# 2     9.162137        H
# 3     3.896371   Double
# 4     3.254143   Triple
# 5     9.741435       HR
# 6     3.804402       BB
# 7     2.652395       SO
# 8     1.895026       SB
# 9   171.126556       RA
# 10  163.993427       ER
# 11    2.814675       CG
# 12    3.480272      SHO
# 13    3.740063       SV
# 14    2.142827        E

# %% [markdown]
# # ML Modelling

# %%
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier

# %%
X = df.drop(columns='W')
y = df['W']

# %%
X_train,y_train,X_test,y_test= train_test_split(X,y,test_size= 0.25, random_state= 42)

# %%
X_train.shape
# Out:
# (22, 16)

# %%
X_test.shape
# Out:
# (22,)

# %%
y_test.shape
# Out:
# (8,)

# %%
y_train.shape
# Out:
# (8, 16)

# %%
max_r2_score = 0
maxRS = 0

for i in range(1,1000):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
    reg = LinearRegression()
    reg.fit(X_train, y_train)
    y_pred = reg.predict(X_test)
    r2score = r2_score(y_test,y_pred)
    print('r2_score', r2score*100,'%', 'random_state', i)
    
    if r2score > max_r2_score:
        max_r2_score = r2score
        maxRS = i
        print('r2_score', max_r2_score*100,'%', 'random_state', i)
# Out:
# r2_score 80.32929426039776 % random_state 1
# r2_score 80.32929426039776 % random_state 1
# r2_score 80.32929426039776 % random_state 2
# r2_score 80.32929426039776 % random_state 3
# r2_score 80.32929426039776 % random_state 4
# r2_score 80.32929426039776 % random_state 5
# r2_score 80.32929426039776 % random_state 6
# r2_score 80.32929426039776 % random_state 7
# r2_score 80.32929426039776 % random_state 8
# r2_score 80.32929426039776 % random_state 9
# r2_score 80.32929426039776 % random_state 10
# r2_score 80.32929426039776 % random_state 11
# r2_score 80.32929426039776 % random_state 12
# r2_score 80.32929426039776 % random_state 13
# r2_score 80.32929426039776 % random_state 14
# r2_score 80.32929426039776 % random_state 15
# r2_score 80.32929426039776 % random_state 16
# r2_score 80.32929426039776 % random_state 17
# r2_score 80.32929426039776 % random_state 18
# r2_score 80.32929426039776 % random_state 19
# r2_score 80.32929426039776 % random_state 20
# r2_score 80.32929426039776 % random_state 21
# r2_score 80.32929426039776 % random_state 22
# r2_score 80.32929426039776 % random_state 23
# r2_score 80.32929426039776 % random_state 24
# r2_score 80.32929426039776 % random_state 25
# r2_score 80.32929426039776 % random_state 26
# r2_score 80.32929426039776 % random_state 27
# r2_score 80.32929426039776 % random_state 28
# r2_score 80.32929426039776 % random_state 29
# r2_score 80.32929426039776 % random_state 30
# r2_score 80.32929426039776 % random_state 31
# r2_score 80.32929426039776 % random_state 32
# r2_score 80.32929426039776 % random_state 33
# r2_score 80.32929426039776 % random_state 34
# r2_score 80.32929426039776 % random_state 35
# r2_score 80.32929426039776 % random_state 36
# r2_score 80.32929426039776 % random_state 37
# r2_score 80.32929426039776 % random_state 38
# r2_score 80.32929426039776 % random_state 988
# r2_score 80.32929426039776 % random_state 989
# r2_score 80.32929426039776 % random_state 990
# r2_score 80.32929426039776 % random_state 991
# r2_score 80.32929426039776 % random_state 992
# r2_score 80.32929426039776 % random_state 993
# r2_score 80.32929426039776 % random_state 994
# r2_score 80.32929426039776 % random_state 995
# r2_score 80.32929426039776 % random_state 996
# r2_score 80.32929426039776 % random_state 997
# r2_score 80.32929426039776 % random_state 998
# r2_score 80.32929426039776 % random_state 999

# %%
print('Best R2 Score is', max_r2_score, 'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.8032929426039777 on Random_state 1

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
print('Intercept:', reg.intercept_)
print('Linear cofficient:', reg.coef_)
# Out:
# Intercept: 113.29181737066185
# Linear cofficient: [ 1.24277205e-01 -1.52133322e-02  2.96356483e-03 -1.47509154e-01
#   1.04562548e-01 -4.21978404e-02 -2.28457918e-02  7.00705868e-04
#   1.70234332e-02  2.38229370e-01 -1.10509451e-01 -3.02631674e+01
#   8.95571951e-01  3.03787574e-01  9.92090429e-01 -8.30606477e-02]

# %%
print('R2 Score:', r2_score(y_test, y_pred))
print('Mean squared error:', mean_squared_error(y_test,y_pred))
print('Mean absolute error:', mean_absolute_error(y_test,y_pred))
print('Square root of mean square error:', np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score: 0.8032929426039777
# Mean squared error: 29.198703832222066
# Mean absolute error: 4.419246025371795
# Square root of mean square error: 5.403582499807148

# %% [markdown]
# since there shouldd be a relationship between independent variable R(runs) and Target variable W(wins). Therefore applying Hypothesis testing to identify whether there  relatiomship exists or not.

# %% [markdown]
# # Hypothesis Testing and P-values

# %% [markdown]
# HO - There is no relationsip between R and W
#
# HA - There is a relationship btween R and W

# %%
import statsmodels.formula.api as smf

# %%
lm = smf.ols(formula = 'W~R' , data = df).fit()

# %%
lm.pvalues
# Out:
# Intercept    0.188745
# R            0.017488
# dtype: float64

# %% [markdown]
# now since the pvalue is less than the alpha value (0.05), we reject the null hypothesis which means there is relation between R and W.

# %%
lm.rsquared
# Out:
# 0.18554602127597375

# %%
lm = LinearRegression()
lm.fit(x_scaled,y)
# Out:
# LinearRegression()

# %%
print('Intercept:', lm.intercept_)
print('R:', lm.coef_[0])
print('AB:', lm.coef_[1])
print('H:', lm.coef_[2])
print('Double:', lm.coef_[3])
print('Triple:', lm.coef_[4])
print('HR:', lm.coef_[5])
print('BB:', lm.coef_[6])
print('SO:', lm.coef_[7])
print('SB:', lm.coef_[8])
print('RA:', lm.coef_[9])
print('CG:', lm.coef_[10])
print('SHO:', lm.coef_[11])
print('SV:', lm.coef_[12])
print('E:', lm.coef_[13])
# Out:
# Intercept: 80.96666666666667
# R: 7.6461071346324685
# AB: 0.5324736599011204
# H: -0.6288755062041923
# Double: -2.3662054954005485
# Triple: 0.1093129575457482
# HR: -1.7988139619350372
# BB: -1.5418910843727718
# SO: 0.2172872736711985
# SB: -0.03886841536986263
# RA: 8.386366206687615
# CG: -13.127790427473338
# SHO: 2.6870833732010135
# SV: 1.36996791427193
# E: 6.152352120083037

# %%
lm = smf.ols(formula = 'W ~ R + AB + Double + Triple + HR + BB + SO + SB +RA + CG + SHO + SV + E', data = df).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      W   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     17.33
# Date:                Tue, 07 May 2024   Prob (F-statistic):           5.34e-07
# Time:                        22:42:14   Log-Likelihood:                -71.770
# No. Observations:                  30   AIC:                             171.5
# Df Residuals:                      16   BIC:                             191.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     35.1956     67.571      0.521      0.610    -108.049     178.440
# R              0.1280      0.029      4.481      0.000       0.067       0.188
# AB             0.0020      0.014      0.139      0.891      -0.028       0.032
# Double        -0.1035      0.071     -1.454      0.165      -0.254       0.047
# Triple        -0.0283      0.110     -0.256      0.801      -0.262       0.206
# HR            -0.0838      0.050     -1.673      0.114      -0.190       0.022
# BB            -0.0116      0.020     -0.572      0.575      -0.055       0.032
# SO             0.0100      0.009      1.055      0.307      -0.010       0.030
# SB            -0.0231      0.037     -0.622      0.543      -0.102       0.056
# RA            -0.0727      0.020     -3.626      0.002      -0.115      -0.030
# CG             0.7649      0.373      2.053      0.057      -0.025       1.555
# SHO            0.1963      0.288      0.682      0.505      -0.414       0.807
# SV             0.6512      0.141      4.612      0.000       0.352       0.951
# E              0.0194      0.058      0.337      0.740      -0.103       0.142
# ==============================================================================
# Omnibus:                        8.725   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                7.068
# Skew:                          -1.028   Prob(JB):                       0.0292
# Kurtosis:                       4.193   Cond. No.                     5.89e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.89e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Observations
# P value for R, HR, SV and RA is very low, that means there is a strong relation between these variables and Win.
#
# p value for E is 0.975, which is very high. we can assume that E does not have any significant effect on Win.
#
# R2 and Adj. R2 values are 0.936 and 0.876 respectively, which means the intercept model is very good.

# %%
lm = smf.ols(formula = 'W ~ R + HR+ RA+SV', data = df).fit()
lm.rsquared
# Out:
# 0.8971237558371723

# %% [markdown]
# it is clear from R2 values for R, HR, RA and SV have correlation of about 89% with Win.

# %%
lm = smf.ols(formula = 'W ~ AB + E', data = df).fit()
lm.rsquared
# Out:
# 0.011956169381316495

# %% [markdown]
# As observed above, AB and E does dont have any significant effect on win as they have only 1.1% correlation with Win.

# %%
lm = smf.ols(formula = 'W ~ H+ Double+Triple+BB+SO+SB+CG+SHO', data = df).fit()
lm.rsquared
# Out:
# 0.5489667438363381

# %% [markdown]
# All other data Points are only 54.8% correlated with Win.

# %%
def print_score(clf, x_train, x_test, y_train, y_test, train = True):
    if train:
        y_pred = clf.predict(x_train)
        print("\n========Train Result==========")
        print(f"R2 score: {r2_score(y_train, y_pred)}")
    elif train==False:
        pred = clf.predict(x_test)
        print("\n========Train Result==========")
        print(f"R2 score: {r2_score(y_train, pred)}")
        print(f"Root Mean Square Error : {np.sqrt(mean_squared_error(y_test, pred))}")

# %%
reg = LinearRegression()

# Regression Model training and printing train and test score
reg.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(reg, x_train, x_test, y_train, y_test, train=True)
# Out:
# ========Train Result==========
# R2 score: 0.9768323432769062

# %%
from sklearn.svm import SVC
svc = SVC()

svc.fit(x_train, y_train)
print_score(svc,x_train,y_train, x_test,y_test, train = True)
# Out:
# ========Train Result==========
# R2 score: 0.7018294516270787

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean squared Error:', mse)
r2 = r2_score(y_test, y_pred)
print('r2 score:', r2)
# Out:
# Mean squared Error: 43.129462499999995
# r2 score: 0.7094436210526316

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
KN = KNeighborsRegressor()
KN.fit(X_train, y_train)
y_pred = KN.predict(X_test)
mse = mean_squared_error(y_test,y_pred)
print('Mean squared Error:', mse)
r2 = r2_score(y_test, y_pred)
print('r2 score:', r2)
# Out:
# Mean squared Error: 59.68000000000001
# r2 score: 0.5979452631578948

# %% [markdown]
# Amongst the ML Models, Linear Regression has the best R2 score. Therefore, Let's perform Cross validation(Ridge and Lasso) and Parameter Tuning(Model Regularization using Ridge and Lasso) on Linear Regression Model.¶

# %% [markdown]
# # Model Regularization Method

# %%
from sklearn.linear_model import Lasso, Ridge, LassoCV, RidgeCV

# %%
lassCV = LassoCV(alphas = None, max_iter = 100, normalize = True)
lassCV.fit(X_train, y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
alpha = lassCV.alpha_
alpha
# Out:
# 0.138667206864744

# %%
lasso_reg = Lasso(alpha)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.138667206864744)

# %%
lasso_reg.score(X_test, y_test)
# Out:
# 0.7941017984621803

# %% [markdown]
# # RidgeCV

# %%
ridgeCV = RidgeCV(alphas = np.arange(0.001,2,0.01), normalize = True)
ridgeCV.fit(X_train,y_train)
# Out:
# RidgeCV(alphas=array([1.000e-03, 1.100e-02, 2.100e-02, 3.100e-02, 4.100e-02, 5.100e-02,
#        6.100e-02, 7.100e-02, 8.100e-02, 9.100e-02, 1.010e-01, 1.110e-01,
#        1.210e-01, 1.310e-01, 1.410e-01, 1.510e-01, 1.610e-01, 1.710e-01,
#        1.810e-01, 1.910e-01, 2.010e-01, 2.110e-01, 2.210e-01, 2.310e-01,
#        2.410e-01, 2.510e-01, 2.610e-01, 2.710e-01, 2.810e-01, 2.910e-01,
#        3.010e-01, 3.110e-01, 3.210e-0...
#        1.621e+00, 1.631e+00, 1.641e+00, 1.651e+00, 1.661e+00, 1.671e+00,
#        1.681e+00, 1.691e+00, 1.701e+00, 1.711e+00, 1.721e+00, 1.731e+00,
#        1.741e+00, 1.751e+00, 1.761e+00, 1.771e+00, 1.781e+00, 1.791e+00,
#        1.801e+00, 1.811e+00, 1.821e+00, 1.831e+00, 1.841e+00, 1.851e+00,
#        1.861e+00, 1.871e+00, 1.881e+00, 1.891e+00, 1.901e+00, 1.911e+00,
#        1.921e+00, 1.931e+00, 1.941e+00, 1.951e+00, 1.961e+00, 1.971e+00,
#        1.981e+00, 1.991e+00]),
#         normalize=True)

# %%
alpha = ridgeCV.alpha_
alpha
# Out:
# 0.17099999999999999

# %%
ridge_model = Ridge(alpha)
ridge_model.fit(X_test,y_test)
# Out:
# Ridge(alpha=0.17099999999999999)

# %%
ridge_model.score(X_test,y_test)
# Out:
# 0.9999999998074348

# %%
import joblib
joblib.dump(reg, "Baseball_Case_Study.pkl")
# Out:
# ['Baseball_Case_Study.pkl']

# %% [markdown]
# # ThankYou
