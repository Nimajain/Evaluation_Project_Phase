# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# So there are 1470 rows and 35 columns. Now lets start the analysis of dataset.

# %%
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
df.tail(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1460                28          4        Medical              1
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# So here we can see that there is no null values are present in the dataset.

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.describe().transpose()
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %% [markdown]
# Count value for all columns are same so the dataset looking perfect.
#
# The value of mean and median(50%) percentile are almost same , the huge difference in between monthly income so we get that outliers are present in monthly income column
#
# In the 75% and max value of Monthly income and Monthly rate has large difference.

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
dfcor = df.corr()
dfcor
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(dfcor, annot = True, cmap = "magma")
plt.title( "Correlation Heatmap", fontsize = 30)
plt.show()

# %%
sns.countplot("Attrition", data = df)
plt.title("Count of Attrition", fontsize = 30)
plt.xlabel("Attrition")
plt.ylabel("Count")
plt.show()

# %%
categorical_cols = [feature for feature in df.columns if df[feature].dtypes == 'object']
df[categorical_cols].sample(5)
# Out:
#      Attrition BusinessTravel              Department EducationField  Gender  \
# 1221        No     Non-Travel  Research & Development  Life Sciences    Male
# 511         No  Travel_Rarely  Research & Development        Medical    Male
# 565         No  Travel_Rarely  Research & Development        Medical    Male
# 342         No  Travel_Rarely  Research & Development        Medical  Female
# 1305        No  Travel_Rarely  Research & Development        Medical  Female
#
#                         JobRole MaritalStatus Over18 OverTime
# 1221  Healthcare Representative       Married      Y       No
# 511      Manufacturing Director      Divorced      Y      Yes
# 565          Research Scientist        Single      Y       No
# 342      Manufacturing Director        Single      Y      Yes
# 1305         Research Scientist       Married      Y       No

# %%
numerical_cols = [feature for feature in df.columns if df[feature].dtypes!='object']
df[numerical_cols].sample(5)
# Out:
#      Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 555   29       1090                10          3              1
# 546   29       1396                10          3              1
# 944   28       1476                 1          3              1
# 861   46       1402                 2          3              1
# 106   50       1115                 1          3              1
#
#      EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 555             766                        4          83               3
# 546             749                        3          99               3
# 944            1315                        3          55               1
# 861            1204                        3          69               3
# 106             141                        1          73               3
#
#      JobLevel  ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
 size = df['BusinessTravel'].value_counts()
 labels = df['BusinessTravel'].unique()

plt.figure(figsize= (6,6))
plt.pie(size, labels = labels, autopct = '%1.1f%%', startangle = 140)
plt.title( 'Percentage of Business Travel of Employee')
plt.show()

# %%
size = df['Department'].value_counts()
labels = df['Department'].unique()

plt.figure(figsize=(6,6))
plt.pie(size, labels = labels, autopct = '%1.1f%%', startangle = 140)
plt.title("Percentage of Department of Employee")
plt.show()

# %%
size = df['EducationField'].value_counts()
labels = df['EducationField'].unique()


plt.figure(figsize=(6,6))
plt.pie( size, labels = labels,  autopct = ' %1.1f%%', startangle = 140)
plt.title("Percentage of Education Field")
plt.show()

# %%
size = df['JobRole'].value_counts()
labels = df['JobRole'].unique()
colors = plt.cm.twilight_r(np.linspace(0,1,9))

plt.figure(figsize=(6,6))
circle = plt.Circle((0,0), radius=0.7, color='white')
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Percentage of Employees in various Job Roles', fontsize=30)
plt.legend(bbox_to_anchor=(0.5, 0., 0.9, 0.9));

# %%
sns.countplot('Gender',data=df )
plt.title("Count of Gender of Employee")
plt.xlabel('Gender')
plt.show()

# %%
size = df['MaritalStatus'].value_counts()
labels = df['MaritalStatus'].unique()
explode = [0.03, 0.03, 0.03]


plt.figure(figsize = (6,6))
plt.pie(size, labels=labels , explode = explode , autopct = '%1.2f%%', startangle = 140)
plt.title("Marital Status of Employee")
plt.show()

# %%
plt.figure(figsize= (10,6))
sns.displot(df['Age'], bins= 30)
plt.title('Distribution of Employee Age ', fontsize=30)
plt.xlabel('Age')
plt.show()

# %%
plt.figure(figsize=(17,6))
sns.countplot('Age', hue='Attrition', data=df)
plt.title('Dependency of Age in determining attrition')
plt.xlabel('Age')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot('Age', 'Attrition', hue= 'Gender', data=df)
plt.title('Attrition w.r.t Age and Gender')
plt.xlabel('Attrition')
plt.show()

# %%
plt.figure(figsize=(19,6))
x= df[['Age', 'DailyRate']].groupby('Age').mean()
x = pd.DataFrame(x)
x.sort_values(by='Age').plot(kind='bar',figsize=(19,6))
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
data = pd.crosstab(df['BusinessTravel'] , df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar',figsize=(19,6), stacked = True)
plt.title('Dependency of Business Travel determining Attrition ')
plt.xlabel('BusinessTravel')
plt.show()

# %%
data = pd.crosstab(df['Department'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar',figsize=(19,6), stacked = True)
plt.title('Dependency of Department in determining Attrition')
plt.xlabel('Department')
plt.show()

# %%
data = pd.crosstab(df['JobRole'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar',figsize=(19,6), stacked = True)
plt.title('Dependency of Job role in determining Attrition')
plt.xlabel('Job Role')
plt.show()

# %%
data = pd.crosstab(df['OverTime'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar',figsize=(19,6), stacked = True)
plt.title('Dependency of Overtime in determining Attrition')
plt.xlabel('Over Time')
plt.show()

# %% [markdown]
# In overtime we see that there is no overtime ,and very less employee are in there job.

# %%
plt.figure(figsize=(10,6))
sns.countplot('RelationshipSatisfaction', hue = 'Attrition',data= df , palette= 'Set1')
plt.title('RelationshipSatisfaction of determining Attrition')
plt.xlabel('Relationship Satisfaction')
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.countplot('YearsAtCompany', hue= 'Attrition', data=df)
plt.title('Years at company determining in Attrition')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot('YearsInCurrentRole', hue= 'Attrition', data=df)
plt.title('Years in current role determining in Attrition')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot('YearsSinceLastPromotion', hue= 'Attrition', data=df)
plt.title('Years since last promotion determining in Attrition')
plt.show()

# %%
data = pd.crosstab(df['YearsWithCurrManager'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar',figsize=(19,6), stacked = True)
plt.title('Dependency of Year with current manager in determining Attrition')
plt.xlabel('YearsWithCurrManager')
plt.show()

# %% [markdown]
# # Analysis Conclusion:

# %% [markdown]
# Why employee leave the organization:
#
# No Overtime This was a surpirse, employees who don't have overtime are most likely to leave the organization. This could be that employees would like to have a higher amount of income or employees could feel that they are underused.
#
# Monthly Income: As expected, Income is a huge factor as why employees leave the organization in search for a better salary.
#
# Age: This could also be expected, since people who are aiming to retire will leave the organization.
#
# Knowing the most likely reasons why employees leave the organization, can help the organization take action and reduce the level of Attrition inside the organization.
